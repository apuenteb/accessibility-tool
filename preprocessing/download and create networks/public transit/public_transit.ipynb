# %% [markdown]
# Load walk+transit network

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import urbanaccess as ua

# Define the file path to your saved network
h5_file_path = "networks/transit_1011.h5"

# Load the network
network = ua.network.load_network(filename=h5_file_path)
# Out:
# Successfully read store: data/networks/transit_1011.h5 with the following keys: ['/edges', '/impedance_names', '/nodes', '/two_way']
# Successfully read store: data/networks/transit_1011.h5 with the following keys: ['/edges', '/impedance_names', '/nodes', '/two_way']

# %%
# Print all available attributes
print(dir(network))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'net_connector_edges', 'net_edges', 'net_nodes', 'osm_edges', 'osm_nodes', 'transit_edges', 'transit_nodes']

# %%
print(network.net_nodes.head())  # Check first rows of nodes
print(network.net_edges.head())  # Check first rows of edges
# Out:
#                x          y
# id_int
# 1      -1.899896  43.318994
# 2      -1.902670  43.314959
# 3      -1.912339  43.317663
# 4      -1.917594  43.318983
# 5      -1.921789  43.320913
#    from  to    weight
# 0     1   2  2.800000
# 1     2   3  2.500000
# 2     3   4  1.150000
# 3     4   5  0.950000
# 4     5   6  1.183333

# %%
node_df = network.net_nodes
print(node_df.head())
# Out:
#                x          y
# id_int
# 1      -1.899896  43.318994
# 2      -1.902670  43.314959
# 3      -1.912339  43.317663
# 4      -1.917594  43.318983
# 5      -1.921789  43.320913

# %%
node_df.reset_index(inplace=True)

# %%
print(node_df.head())
# Out:
#    id_int         x          y
# 0       1 -1.899896  43.318994
# 1       2 -1.902670  43.314959
# 2       3 -1.912339  43.317663
# 3       4 -1.917594  43.318983
# 4       5 -1.921789  43.320913

# %%
edge_df = network.net_edges
print(edge_df.head())
# Out:
#    from  to    weight
# 0     1   2  2.800000
# 1     2   3  2.500000
# 2     3   4  1.150000
# 3     4   5  0.950000
# 4     5   6  1.183333

# %%
print(node_df.columns)
# Out:
# Index(['id_int', 'x', 'y'], dtype='object')

# %%
import pandas as pd

# Merge using the updated 'id_int' column instead of 'id'
tmp = pd.merge(edge_df, node_df[['id_int']], left_on='from', right_index=True, sort=False, copy=False, how='left')

# Assign the 'from_int' column based on 'id_int' from node_df
tmp['from_int'] = tmp['id_int']

# Drop the unnecessary columns
tmp.drop(['id_int'], axis=1, inplace=True)

# Check the resulting dataframe
print(tmp.head())
# Out:
#    from  to    weight  from_int
# 0     1   2  2.800000       2.0
# 1     2   3  2.500000       3.0
# 2     3   4  1.150000       4.0
# 3     4   5  0.950000       5.0
# 4     5   6  1.183333       6.0

# %%
# Merge to get the 'to_int' column
tmp = pd.merge(tmp, node_df[['id_int']], left_on='to', right_index=True, sort=False, copy=False, how='left')

# Assign the 'to_int' column based on 'id_int' from node_df
tmp['to_int'] = tmp['id_int']

# Drop the unnecessary columns
tmp.drop(['id_int'], axis=1, inplace=True)

# Check the resulting dataframe
print(tmp.head())
# Out:
#    from  to    weight  from_int  to_int
# 0     1   2  2.800000       2.0     3.0
# 1     2   3  2.500000       3.0     4.0
# 2     3   4  1.150000       4.0     5.0
# 3     4   5  0.950000       5.0     6.0
# 4     5   6  1.183333       6.0     7.0

# %%
node_df.rename(columns={'id_int': 'id'}, inplace=True)
print(node_df.head())
# Out:
#    id         x          y
# 0   1 -1.899896  43.318994
# 1   2 -1.902670  43.314959
# 2   3 -1.912339  43.317663
# 3   4 -1.917594  43.318983
# 4   5 -1.921789  43.320913

# %%
network_formated=ua.network._format_pandana_edges_nodes(edge_df, node_df)
# Out:
# Edge and node tables formatted for Pandana with integer node ids: id_int, to_int, and from_int. Took 0.51 seconds

# %%
print(network_formated)
# Out:
# (         from     to    weight  from_int  to_int
# 0           1      2  2.800000         1       2
# 1           2      3  2.500000         2       3
# 2           3      4  1.150000         3       4
# 3           4      5  0.950000         4       5
# 4           5      6  1.183333         5       6
# ...       ...    ...       ...       ...     ...
# 423704   4202  64640  0.308245      4202   64640
# 423705  64640   4202  7.808245     64640    4202
# 423706  64640   4202  7.808245     64640    4202
# 423707  64640   4202  7.808245     64640    4202
# 423708  64640   4202  7.808245     64640    4202
#
# [423709 rows x 5 columns],             id         x          y
# id_int
# 1            1 -1.899896  43.318994
# 2            2 -1.902670  43.314959
# 3            3 -1.912339  43.317663
# 4            4 -1.917594  43.318983
# 5            5 -1.921789  43.320913
# ...        ...       ...        ...
# 125262  125262 -2.211893  43.298687
# 125263  125263 -2.213562  43.296225
# 125264  125264 -2.214446  43.295336
# 125265  125265 -2.215143  43.294580
# 125266  125266 -2.216141  43.037996
#
# [125266 rows x 3 columns])

# %%
df = network_formated[0]  # Extract the DataFrame

for i in range(5):
    print(df['from'].iloc[i], df['to'].iloc[i], df['weight'].iloc[i])
# Out:
# 1 2 2.8
# 2 3 2.5
# 3 4 1.15
# 4 5 0.95
# 5 6 1.1833333333333333

# %%
edges_df, nodes_df = network_formated

# %%
print(nodes_df.columns)  # Should work if nodes_df is a DataFrame
# Out:
# Index(['id', 'x', 'y'], dtype='object')

# %%
print(edges_df.columns)  # Should work if edges_df is a DataFrame
# Out:
# Index(['from', 'to', 'weight', 'from_int', 'to_int'], dtype='object')

# %%
import pandana

# Extract the 'from_int', 'to_int', and 'weight' columns for the edges
imp = pd.DataFrame(edges_df['weight'])

# Create a Pandana network
pt_network = pandana.Network(nodes_df.x, nodes_df.y, 
                      edges_df.from_int, edges_df.to_int, imp, False)

# %% [markdown]
# Use the network (check that it works properly)

# %%
O_lat,O_lon=[43.304787562955205, -2.0162325112056965]

O_nodes = pt_network.get_node_ids([O_lon], [O_lat]).values
O_nodes

D_lat,D_lon=[43.313605588539566, -2.0054322679462913]

D_nodes = pt_network.get_node_ids([D_lon], [D_lat]).values
D_nodes

# Convert both node arrays to integers (if they are not already)
O_nodes = O_nodes.astype(int)
D_nodes = D_nodes.astype(int)

# Now calculate the shortest path length
pt_network.shortest_path_length(O_nodes[0], D_nodes[0])
# Out:
# 13.876

# %%
import geopandas as gpd
import pandas as pd
from shapely.geometry import Point, LineString

# Assuming 'network' is your Pandana network
nodes_gdf = gpd.GeoDataFrame(
    pt_network.nodes_df,
    geometry=[Point(xy) for xy in zip(pt_network.nodes_df['x'], pt_network.nodes_df['y'])],
    crs="EPSG:4326"  # Ensure it's in WGS84 for compatibility with Kepler
)

# Save nodes to GeoJSON
nodes_gdf.to_file("nodes.geojson", driver="GeoJSON")

# %%
import geopandas as gpd
from shapely.geometry import LineString, Point
import pandas as pd
import pandana as pdna

# Example data
# Assuming 'network_formated' is your edges DataFrame
# Assuming 'nodes_df' is your nodes DataFrame

# Get the nearest nodes for origin and destination using your logic
O_lat, O_lon = [43.304795980913255, -2.0160877677716376]
D_lat, D_lon = [43.305456412997316, -2.0167954816992952]

O_nodes = pt_network.get_node_ids([O_lon], [O_lat]).values.astype(int)
D_nodes = pt_network.get_node_ids([D_lon], [D_lat]).values.astype(int)

# Calculate the shortest path between the origin and destination
shortest_path_nodes = pt_network.shortest_path(O_nodes[0], D_nodes[0])

# print the shortest path length
print(pt_network.shortest_path_length(O_nodes[0], D_nodes[0]))

# Ensure the shortest path is valid
if len(shortest_path_nodes) == 0:
    raise ValueError("Shortest path calculation failed. The path is empty!")

# Extract coordinates for the nodes involved in the shortest path
# Accessing the 'nodes_df' which holds the x, y coordinates
path_coords = [(nodes_df.loc[node, 'x'], nodes_df.loc[node, 'y']) for node in shortest_path_nodes]

# Ensure we have at least 2 valid points
if len(path_coords) < 2:
    raise ValueError(f"Not enough valid coordinates found! Found only {len(path_coords)} points.")

# Create a LineString geometry from the coordinates
route_geometry = LineString(path_coords)

# Create a list of Point geometries for the nodes
node_geometries = [Point(nodes_df.loc[node, 'x'], nodes_df.loc[node, 'y']) for node in shortest_path_nodes]

# Create a GeoDataFrame to store the route and the nodes
route_gdf = gpd.GeoDataFrame([{
    'origin_node': O_nodes[0],
    'destination_node': D_nodes[0],
    'length': pt_network.shortest_path_length(O_nodes[0], D_nodes[0]),
    'geometry': route_geometry
}], crs="EPSG:4326")

# Add node geometries to the same GeoDataFrame as individual nodes
nodes_gdf = gpd.GeoDataFrame([{
    'node_id': node,
    'geometry': geom
} for node, geom in zip(shortest_path_nodes, node_geometries)], crs="EPSG:4326")

# Combine the route and nodes GeoDataFrames into a single GeoDataFrame
combined_gdf = pd.concat([route_gdf, nodes_gdf], ignore_index=True)

# Save the combined route and nodes to a GeoJSON file
combined_gdf.to_file("shortest_route_with_nodes.geojson", driver="GeoJSON")

print("Route and nodes successfully saved as shortest_route_with_nodes.geojson")
# Out:
# 11.231
# Route and nodes successfully saved as shortest_route_with_nodes.geojson

# %% [markdown]
# Load nodes gdf

# %%
import geopandas as gpd

# Load the geojson file and print to check
nodes_gdf = gpd.read_file('./data/geojson/building_nodes_with_poi.geojson')

print(nodes_gdf.head())
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[269], line 4
#       1 import geopandas as gpd
#       3 # Load the geojson file and print to check
# ----> 4 nodes_gdf = gpd.read_file('./data/geojson/building_nodes_with_poi.geojson')
#       6 print(nodes_gdf.head())
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\geopandas\io\file.py:294, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     291             from_bytes = True
#     293 if engine == "pyogrio":
# --> 294     return _read_file_pyogrio(
#     295         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     296     )
#     298 elif engine == "fiona":
#     299     if pd.api.types.is_file_like(filename):
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\geopandas\io\file.py:547, in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     538     warnings.warn(
#     539         "The 'include_fields' and 'ignore_fields' keywords are deprecated, and "
#     540         "will be removed in a future release. You can use the 'columns' keyword "
#    (...)
#     543         stacklevel=3,
#     544     )
#     545     kwargs["columns"] = kwargs.pop("include_fields")
# --> 547 return pyogrio.read_dataframe(path_or_bytes, bbox=bbox, **kwargs)
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyogrio\geopandas.py:313, in read_dataframe(path_or_buffer, layer, encoding, columns, read_geometry, force_2d, skip_features, max_features, where, bbox, mask, fids, sql, sql_dialect, fid_as_index, use_arrow, on_invalid, arrow_to_pandas_kwargs, **kwargs)
#     309         return df
#     311 meta, index, geometry, field_data = result
# --> 313 columns = meta["fields"].tolist()
#     314 data = {columns[i]: field_data[i] for i in range(len(columns))}
#     315 if fid_as_index:
#
# KeyboardInterrupt:

# %%
# Fill the time_to_poi column with None
nodes_gdf['nearest_node'] = None
nodes_gdf['time_to_nearest_poi'] = None
nodes_gdf['block_color'] = None
nodes_gdf['nearest_poi'] = None
nodes_gdf['nearest_poi_node'] = None
print(nodes_gdf.head())
# Out:
#   Referencia       lon        lat nearest_node time_to_nearest_poi  \
# 0    8594095 -1.948183  43.299723         None                None
# 1    8594099 -1.948484  43.299120         None                None
# 2    8594100 -1.948365  43.298748         None                None
# 3    8796114 -1.928046  43.315046         None                None
# 4    8796136 -1.928175  43.313904         None                None
#
#   block_color nearest_poi nearest_poi_node                   geometry
# 0        None        None             None  POINT (-1.94818 43.29972)
# 1        None        None             None  POINT (-1.94848 43.29912)
# 2        None        None             None  POINT (-1.94837 43.29875)
# 3        None        None             None  POINT (-1.92805 43.31505)
# 4        None        None             None   POINT (-1.92818 43.3139)

# %% [markdown]
# Load POI gdf

# %%
poi = gpd.read_file('./data/poi/centros_salud.geojson')
print(poi.head())
# Out:
#                        nombre codigodelcentro     tipodecentro  \
# 0  Ambulatorio de Amara Berri  entity2C9E9AC2      Ambulatorio
# 1  Ambulatorio de Amara Berri  entityD96EC52F  Centro de Salud
# 2     Ambulatorio de Azpeitia  entity458B7E4D      Ambulatorio
# 3     Ambulatorio de Azpeitia  entity88E353B4  Centro de Salud
# 4      Ambulatorio de Beasain  entity24E39531  Centro de Salud
#
#                    horarioatencionciudadana  \
# 0  De lunes a viernes de 08:00 h a 20:00 h.
# 1                                      None
# 2       de lunes a viernes de 08:00 a 20:00
# 3                                      None
# 4                                      None
#
#                                      horarioespecial  \
# 0  Para urgencias leves fuera del horario del Cen...
# 1                                               None
# 2  para urgencias leves fuera del horario del Cen...
# 3                                               None
# 4                                               None
#
#                             aliasdelcentro  \
# 0               ambulatorio-de-amara-berri
# 1  ambulatorio-de-amara-berri/centro-salud
# 2                  ambulatorio-de-azpeitia
# 3     ambulatorio-de-azpeitia/centro-salud
# 4      ambulatorio-de-beasain/centro-salud
#
#                  hospitaldereferencia  \
# 0  Hospital Universitario de Donostia
# 1  Hospital Universitario de Donostia
# 2               Hospital de Zumarraga
# 3                     PAC DE AZPEITIA
# 4               Hospital de Zumarraga
#
#                                    horariodeurgencia  \
# 0  PERSONAS ADULTAS De lunes a viernes: De 8:00 h...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                            direccion  \
# 0  Javier Barkaiztegi, 18, 20010 Donostia / San S...
# 1  Javier Barkaiztegi, 18, 20010 Donostia / San S...
# 2         Jose Artetxe, 7, 20730 Azpeitia (Gipuzkoa)
# 3         Jose Artetxe, 7, 20730 Azpeitia (Gipuzkoa)
# 4          Bernedo Enea, 1, 20200 Beasain (Gipuzkoa)
#
#                                             comarca                 municipio  \
# 0     OSI Donostialdea > Ambulatorio de Amara Berri  Donostia / San Sebastián
# 1                        Ambulatorio de Amara Berri  Donostia / San Sebastián
# 2  OSI Goierri-Alto Urola > Ambulatorio de Azpeitia                  Azpeitia
# 3                           Ambulatorio de Azpeitia                  Azpeitia
# 4                            Ambulatorio de Beasain                   Beasain
#
#   codigopostal provincia   telefono        fax  \
# 0        20010  Gipuzkoa  943007900  943007919
# 1        20010  Gipuzkoa  943007900  943007919
# 2        20730  Gipuzkoa  943025400       None
# 3        20730  Gipuzkoa       None       None
# 4        20200  Gipuzkoa  943027700       None
#
#                     correoelectronico                   geometry
# 0  correo.csamaraberri@osakidetza.eus    POINT (-1.982 43.30597)
# 1  correo.csamaraberri@osakidetza.eus    POINT (-1.982 43.30597)
# 2             AZPEITIA@osakidetza.eus  POINT (-2.26798 43.18144)
# 3                                None  POINT (-2.26798 43.18144)
# 4              BEASAIN@osakidetza.eus   POINT (-2.1977 43.04528)

# %%
poi['lon'] = poi['geometry'].x
poi['lat'] = poi['geometry'].y

# %% [markdown]
# Create functions to find nearest node

# %%
def assign_nearest_nodes(gdf, pt_network):
    # Ensure lon/lat are numeric
    gdf['lon'] = pd.to_numeric(gdf['lon'], errors='coerce')
    gdf['lat'] = pd.to_numeric(gdf['lat'], errors='coerce')

    # Drop rows with missing coordinates
    gdf = gdf.dropna(subset=['lon', 'lat']).copy()
    
    # Convert to numpy arrays
    lon_values = gdf['lon'].to_numpy()
    lat_values = gdf['lat'].to_numpy()

    # Assign nearest nodes
    try:
        gdf['nearest_node'] = pt_network.get_node_ids(lon_values, lat_values)
    except Exception as e:
        print(f"Error assigning nearest nodes: {e}")
        gdf['nearest_node'] = None  # Assign None in case of failure

    return gdf

# %%
nodes_gdf = assign_nearest_nodes(nodes_gdf, pt_network)
print(nodes_gdf.head())
# Out:
#   Referencia       lon        lat  nearest_node time_to_nearest_poi  \
# 0    8594095 -1.948183  43.299723         39049                None
# 1    8594099 -1.948484  43.299120         39049                None
# 2    8594100 -1.948365  43.298748         39049                None
# 3    8796114 -1.928046  43.315046         16476                None
# 4    8796136 -1.928175  43.313904         16476                None
#
#   block_color nearest_poi nearest_poi_node                   geometry
# 0        None        None             None  POINT (-1.94818 43.29972)
# 1        None        None             None  POINT (-1.94848 43.29912)
# 2        None        None             None  POINT (-1.94837 43.29875)
# 3        None        None             None  POINT (-1.92805 43.31505)
# 4        None        None             None   POINT (-1.92818 43.3139)

# %%
poi = assign_nearest_nodes(poi, pt_network)
print(poi.head())
# Out:
#                        nombre codigodelcentro     tipodecentro  \
# 0  Ambulatorio de Amara Berri  entity2C9E9AC2      Ambulatorio
# 1  Ambulatorio de Amara Berri  entityD96EC52F  Centro de Salud
# 2     Ambulatorio de Azpeitia  entity458B7E4D      Ambulatorio
# 3     Ambulatorio de Azpeitia  entity88E353B4  Centro de Salud
# 4      Ambulatorio de Beasain  entity24E39531  Centro de Salud
#
#                    horarioatencionciudadana  \
# 0  De lunes a viernes de 08:00 h a 20:00 h.
# 1                                      None
# 2       de lunes a viernes de 08:00 a 20:00
# 3                                      None
# 4                                      None
#
#                                      horarioespecial  \
# 0  Para urgencias leves fuera del horario del Cen...
# 1                                               None
# 2  para urgencias leves fuera del horario del Cen...
# 3                                               None
# 4                                               None
#
#                             aliasdelcentro  \
# 0               ambulatorio-de-amara-berri
# 1  ambulatorio-de-amara-berri/centro-salud
# 2                  ambulatorio-de-azpeitia
# 3     ambulatorio-de-azpeitia/centro-salud
# 4      ambulatorio-de-beasain/centro-salud
#
#                  hospitaldereferencia  \
# 0  Hospital Universitario de Donostia
# 1  Hospital Universitario de Donostia
# 2               Hospital de Zumarraga
# 3                     PAC DE AZPEITIA
# 4               Hospital de Zumarraga
#
#                                    horariodeurgencia  \
# 0  PERSONAS ADULTAS De lunes a viernes: De 8:00 h...
# 1                                               None
# 2                                               None
# 3                                               None
# 4                                               None
#
#                                            direccion  \
# 0  Javier Barkaiztegi, 18, 20010 Donostia / San S...
# 1  Javier Barkaiztegi, 18, 20010 Donostia / San S...
# 2         Jose Artetxe, 7, 20730 Azpeitia (Gipuzkoa)
# 3         Jose Artetxe, 7, 20730 Azpeitia (Gipuzkoa)
# 4          Bernedo Enea, 1, 20200 Beasain (Gipuzkoa)
#
#                                             comarca                 municipio  \
# 0     OSI Donostialdea > Ambulatorio de Amara Berri  Donostia / San Sebastián
# 1                        Ambulatorio de Amara Berri  Donostia / San Sebastián
# 2  OSI Goierri-Alto Urola > Ambulatorio de Azpeitia                  Azpeitia
# 3                           Ambulatorio de Azpeitia                  Azpeitia
# 4                            Ambulatorio de Beasain                   Beasain
#
#   codigopostal provincia   telefono        fax  \
# 0        20010  Gipuzkoa  943007900  943007919
# 1        20010  Gipuzkoa  943007900  943007919
# 2        20730  Gipuzkoa  943025400       None
# 3        20730  Gipuzkoa       None       None
# 4        20200  Gipuzkoa  943027700       None
#
#                     correoelectronico                   geometry       lon  \
# 0  correo.csamaraberri@osakidetza.eus    POINT (-1.982 43.30597) -1.982001
# 1  correo.csamaraberri@osakidetza.eus    POINT (-1.982 43.30597) -1.982001
# 2             AZPEITIA@osakidetza.eus  POINT (-2.26798 43.18144) -2.267977
# 3                                None  POINT (-2.26798 43.18144) -2.267977
# 4              BEASAIN@osakidetza.eus   POINT (-2.1977 43.04528) -2.197701
#
#          lat  nearest_node
# 0  43.305973         99200
# 1  43.305973         99200
# 2  43.181437          5103
# 3  43.181437          5103
# 4  43.045277         18168

# %% [markdown]
# Find nearest POI for each node

# %%
from shapely.geometry import Point

def nearest_poi(row, poi_df):
    # Asegúrate de usar la geometría para calcular la distancia
    distances = poi['geometry'].apply(lambda x: row.geometry.distance(x))
    nearest = poi.loc[distances.idxmin()]
    return nearest['nombre']  # O el identificador que quieras retornar

# Aplica la función sobre cada fila del GeoDataFrame
nodes_gdf['nearest_poi'] = nodes_gdf.apply(nearest_poi, poi_df=poi, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[124], line 10
#       7     return nearest['nombre']  # O el identificador que quieras retornar
#       9 # Aplica la función sobre cada fila del GeoDataFrame
# ---> 10 nodes_gdf['nearest_poi'] = nodes_gdf.apply(nearest_poi, poi_df=poi, axis=1)
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\geopandas\geodataframe.py:1834, in GeoDataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    1832 @doc(pd.DataFrame)
#    1833 def apply(self, func, axis=0, raw=False, result_type=None, args=(), **kwargs):
# -> 1834     result = super().apply(
#    1835         func, axis=axis, raw=raw, result_type=result_type, args=args, **kwargs
#    1836     )
#    1837     # Reconstruct gdf if it was lost by apply
#    1838     if (
#    1839         isinstance(result, DataFrame)
#    1840         and self._geometry_column_name in result.columns
#    1841     ):
#    1842         # axis=1 apply will split GeometryDType to object, try and cast back
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[124], line 5, in nearest_poi(row, poi_df)
#       3 def nearest_poi(row, poi_df):
#       4     # Asegúrate de usar la geometría para calcular la distancia
# ----> 5     distances = poi['geometry'].apply(lambda x: row.geometry.distance(x))
#       6     nearest = poi.loc[distances.idxmin()]
#       7     return nearest['nombre']
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\geopandas\geoseries.py:752, in GeoSeries.apply(self, func, convert_dtype, args, **kwargs)
#     749         kwargs["convert_dtype"] = True
#     751 # to avoid warning
# --> 752 result = super().apply(func, args=args, **kwargs)
#     753 if isinstance(result, GeoSeries):
#     754     if self.crs is not None:
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\base.py:919, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     916 arr = self._values
#     918 if isinstance(arr, ExtensionArray):
# --> 919     return arr.map(mapper, na_action=na_action)
#     921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\arrays\base.py:2322, in ExtensionArray.map(self, mapper, na_action)
#    2302 def map(self, mapper, na_action=None):
#    2303     """
#    2304     Map values using an input mapping or function.
#    2305
#    (...)
#    2320         a MultiIndex will be returned.
#    2321     """
# -> 2322     return map_array(self, mapper, na_action=na_action)
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[124], line 5, in nearest_poi.<locals>.<lambda>(x)
#       3 def nearest_poi(row, poi_df):
#       4     # Asegúrate de usar la geometría para calcular la distancia
# ----> 5     distances = poi['geometry'].apply(lambda x: row.geometry.distance(x))
#       6     nearest = poi.loc[distances.idxmin()]
#       7     return nearest['nombre']
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\shapely\geometry\base.py:334, in BaseGeometry.distance(self, other)
#     332 def distance(self, other):
#     333     """Unitless distance to other geometry (float)"""
# --> 334     return _maybe_unpack(shapely.distance(self, other))
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\shapely\decorators.py:77, in multithreading_enabled.<locals>.wrapped(*args, **kwargs)
#      75     for arr in array_args:
#      76         arr.flags.writeable = False
# ---> 77     return func(*args, **kwargs)
#      78 finally:
#      79     for arr, old_flag in zip(array_args, old_flags):
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\shapely\measurement.py:72, in distance(a, b, **kwargs)
#      47 @multithreading_enabled
#      48 def distance(a, b, **kwargs):
#      49     """Computes the Cartesian distance between two geometries.
#      50
#      51     Parameters
#    (...)
#      70     nan
#      71     """
# ---> 72     return lib.distance(a, b, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# Assign the nearest node of the nearest POI

# %%
nodes_gdf['nearest_poi_node'] = None

# Get the nearest node of the nearest poi that is already in the poi dataframe
def nearest_poi_node(row):
    nearest_node = poi.loc[row['nearest_poi'] == poi['nombre']]['nearest_node']
    return nearest_node.values[0]

# %%
# Apply the function to each row in the GeoDataFrame
nodes_gdf['nearest_poi_node'] = nodes_gdf.apply(nearest_poi_node, axis=1)

# %%
print(nodes_gdf.head())
# Out:
#   Referencia       lon        lat  nearest_node time_to_nearest_poi  \
# 0    8594095 -1.948183  43.299723         39049                None
# 1    8594099 -1.948484  43.299120         39049                None
# 2    8594100 -1.948365  43.298748         39049                None
# 3    8796114 -1.928046  43.315046         16476                None
# 4    8796136 -1.928175  43.313904         16476                None
#
#   block_color                                        nearest_poi  \
# 0        None  Centro de Salud de Martutene (Centro Penitenci...
# 1        None  Centro de Salud de Martutene (Centro Penitenci...
# 2        None  Centro de Salud de Martutene (Centro Penitenci...
# 3        None                           Centro de Salud de Altza
# 4        None                           Centro de Salud de Altza
#
#    nearest_poi_node                   geometry
# 0            115848  POINT (-1.94818 43.29972)
# 1            115848  POINT (-1.94848 43.29912)
# 2            115848  POINT (-1.94837 43.29875)
# 3             81522  POINT (-1.92805 43.31505)
# 4             81522   POINT (-1.92818 43.3139)

# %% [markdown]
# Find shortest path

# %%
# Define a function to compute shortest path length for each row
def compute_shortest_path(row, pt_network):
    # Extract nearest node and nearest POI node
    origin_node = row['nearest_node']
    destination_node = row['nearest_poi_node']
    
    # Calculate the shortest path length between the two nodes
    path_length = pt_network.shortest_path_length(origin_node, destination_node)
    print(f"Shortest path length: {path_length} for row {row.name}")
    
    return path_length

# Apply the function to each row of the GeoDataFrame
nodes_gdf['time_to_nearest_poi'] = nodes_gdf.apply(compute_shortest_path, pt_network=pt_network, axis=1)
# Out:
# Shortest path length: 13.293 for row 0
# Shortest path length: 13.293 for row 1
# Shortest path length: 13.293 for row 2
# Shortest path length: 5.64 for row 3
# Shortest path length: 5.64 for row 4
# Shortest path length: 3.03 for row 5
# Shortest path length: 1.733 for row 6
# Shortest path length: 3.411 for row 7
# Shortest path length: 3.411 for row 8
# Shortest path length: 14.561 for row 9
# Shortest path length: 13.606 for row 10
# Shortest path length: 24.51 for row 11
# Shortest path length: 18.884 for row 12
# Shortest path length: 10.676 for row 13
# Shortest path length: 10.676 for row 14
# Shortest path length: 19.506 for row 15
# Shortest path length: 7.469 for row 16
# Shortest path length: 27.613 for row 17
# Shortest path length: 10.676 for row 18
# Shortest path length: 7.523 for row 19
# Shortest path length: 9.458 for row 20
# Shortest path length: 10.283 for row 21
# Shortest path length: 26.601 for row 22
# Shortest path length: 8.912 for row 23
# Shortest path length: 10.477 for row 24
# Shortest path length: 10.055 for row 25
# Shortest path length: 15.845 for row 26
# Shortest path length: 13.862 for row 27
# Shortest path length: 9.67 for row 28
# Shortest path length: 22.552 for row 29
# Shortest path length: 11.185 for row 30
# Shortest path length: 12.823 for row 31
# Shortest path length: 11.723 for row 32
# Shortest path length: 7.967 for row 33
# Shortest path length: 11.897 for row 34
# Shortest path length: 11.723 for row 35
# Shortest path length: 7.789 for row 36
# Shortest path length: 23.807 for row 37
# Shortest path length: 14.128 for row 38
# Shortest path length: 11.271 for row 39
# Shortest path length: 23.239 for row 40
# Shortest path length: 18.286 for row 41
# Shortest path length: 9.732 for row 42
# Shortest path length: 27.67 for row 43
# Shortest path length: 12.872 for row 44
# Shortest path length: 25.359 for row 45
# Shortest path length: 12.872 for row 46
# Shortest path length: 11.259 for row 47
# Shortest path length: 16.947 for row 48
# Shortest path length: 8.98 for row 49
# Shortest path length: 12.162 for row 50
# Shortest path length: 20.23 for row 51
# Shortest path length: 20.23 for row 52
# Shortest path length: 8.827 for row 53
# Shortest path length: 10.55 for row 54
# Shortest path length: 10.188 for row 55
# Shortest path length: 15.589 for row 56
# Shortest path length: 16.533 for row 57
# Shortest path length: 14.01 for row 58
# Shortest path length: 12.693 for row 59
# Shortest path length: 11.782 for row 60
# Shortest path length: 14.763 for row 61
# Shortest path length: 25.362 for row 62
# Shortest path length: 19.506 for row 63
# Shortest path length: 7.345 for row 64
# Shortest path length: 5.632 for row 65
# Shortest path length: 19.517 for row 66
# Shortest path length: 10.121 for row 67
# Shortest path length: 9.2 for row 68
# Shortest path length: 4.675 for row 69
# Shortest path length: 3.926 for row 70
# Shortest path length: 12.108 for row 71
# Shortest path length: 7.997 for row 72
# Shortest path length: 5.796 for row 73
# Shortest path length: 6.208 for row 74
# Shortest path length: 6.752 for row 75
# Shortest path length: 6.545 for row 76
# Shortest path length: 6.829 for row 77
# Shortest path length: 32.494 for row 78
# Shortest path length: 7.89 for row 79
# Shortest path length: 31.362 for row 80
# Shortest path length: 5.796 for row 81
# Shortest path length: 32.255 for row 82
# Shortest path length: 6.208 for row 83
# Shortest path length: 7.391 for row 84
# Shortest path length: 6.752 for row 85
# Shortest path length: 21.315 for row 86
# Shortest path length: 10.732 for row 87
# Shortest path length: 9.231 for row 88
# Shortest path length: 4.482 for row 89
# Shortest path length: 7.422 for row 90
# Shortest path length: 7.636 for row 91
# Shortest path length: 14.625 for row 92
# Shortest path length: 17.199 for row 93
# Shortest path length: 17.199 for row 94
# Shortest path length: 20.933 for row 95
# Shortest path length: 14.749 for row 96
# Shortest path length: 7.422 for row 97
# Shortest path length: 7.422 for row 98
# Shortest path length: 12.264 for row 99
# Shortest path length: 21.101 for row 100
# Shortest path length: 12.522 for row 101
# Shortest path length: 23.241 for row 102
# Shortest path length: 12.522 for row 103
# Shortest path length: 19.454 for row 104
# Shortest path length: 18.279 for row 105
# Shortest path length: 18.802 for row 106
# Shortest path length: 20.036 for row 107
# Shortest path length: 20.036 for row 108
# Shortest path length: 4.919 for row 109
# Shortest path length: 19.494 for row 110
# Shortest path length: 6.241 for row 111
# Shortest path length: 10.8 for row 112
# Shortest path length: 9.142 for row 113
# Shortest path length: 20.23 for row 114
# Shortest path length: 7.599 for row 115
# Shortest path length: 4.861 for row 116
# Shortest path length: 9.406 for row 117
# Shortest path length: 9.913 for row 118
# Shortest path length: 9.477 for row 119
# Shortest path length: 16.335 for row 120
# Shortest path length: 8.585 for row 121
# Shortest path length: 8.098 for row 122
# Shortest path length: 18.453 for row 123
# Shortest path length: 8.098 for row 124
# Shortest path length: 17.149 for row 125
# Shortest path length: 16.885 for row 126
# Shortest path length: 7.42 for row 127
# Shortest path length: 7.568 for row 128
# Shortest path length: 7.775 for row 129
# Shortest path length: 6.992 for row 130
# Shortest path length: 18.802 for row 131
# Shortest path length: 6.527 for row 132
# Shortest path length: 25.728 for row 133
# Shortest path length: 6.164 for row 134
# Shortest path length: 22.048 for row 135
# Shortest path length: 29.923 for row 136
# Shortest path length: 5.547 for row 137
# Shortest path length: 25.728 for row 138
# Shortest path length: 26.024 for row 139
# Shortest path length: 26.707 for row 140
# Shortest path length: 7.079 for row 141
# Shortest path length: 6.606 for row 142
# Shortest path length: 15.346 for row 143
# Shortest path length: 13.737 for row 144
# Shortest path length: 10.632 for row 145
# Shortest path length: 10.225 for row 146
# Shortest path length: 10.225 for row 147
# Shortest path length: 9.778 for row 148
# Shortest path length: 3.279 for row 149
# Shortest path length: 18.881 for row 150
# Shortest path length: 5.334 for row 151
# Shortest path length: 10.115 for row 152
# Shortest path length: 8.943 for row 153
# Shortest path length: 11.457 for row 154
# Shortest path length: 22.182 for row 155
# Shortest path length: 21.38 for row 156
# Shortest path length: 26.655 for row 157
# Shortest path length: 11.635 for row 158
# Shortest path length: 5.047 for row 159
# Shortest path length: 14.493 for row 160
# Shortest path length: 10.753 for row 161
# Shortest path length: 11.635 for row 162
# Shortest path length: 10.581 for row 163
# Shortest path length: 5.047 for row 164
# Shortest path length: 11.635 for row 165
# Shortest path length: 77.324 for row 166
# Shortest path length: 77.324 for row 167
# Shortest path length: 11.457 for row 168
# Shortest path length: 10.557 for row 169
# Shortest path length: 17.548 for row 170
# Shortest path length: 11.81 for row 171
# Shortest path length: 11.34 for row 172
# Shortest path length: 20.9 for row 173
# Shortest path length: 22.42 for row 174
# Shortest path length: 22.42 for row 175
# Shortest path length: 25.265 for row 176
# Shortest path length: 13.527 for row 177
# Shortest path length: 24.903 for row 178
# Shortest path length: 25.488 for row 179
# Shortest path length: 25.708 for row 180
# Shortest path length: 25.444 for row 181
# Shortest path length: 26.738 for row 182
# Shortest path length: 19.231 for row 183
# Shortest path length: 5.45 for row 184
# Shortest path length: 28.738 for row 185
# Shortest path length: 34.582 for row 186
# Shortest path length: 7.752 for row 187
# Shortest path length: 22.595 for row 188
# Shortest path length: 36.652 for row 189
# Shortest path length: 23.976 for row 190
# Shortest path length: 8.265 for row 191
# Shortest path length: 26.766 for row 192
# Shortest path length: 19.56 for row 193
# Shortest path length: 22.887 for row 194
# Shortest path length: 19.634 for row 195
# Shortest path length: 21.243 for row 196
# Shortest path length: 5.45 for row 197
# Shortest path length: 8.638 for row 198
# Shortest path length: 26.467 for row 199
# Shortest path length: 5.45 for row 200
# Shortest path length: 8.638 for row 201
# Shortest path length: 5.763 for row 202
# Shortest path length: 5.536 for row 203
# Shortest path length: 5.909 for row 204
# Shortest path length: 0.813 for row 205
# Shortest path length: 5.797 for row 206
# Shortest path length: 6.163 for row 207
# Shortest path length: 6.004 for row 208
# Shortest path length: 11.72 for row 209
# Shortest path length: 26.157 for row 210
# Shortest path length: 28.031 for row 211
# Shortest path length: 24.51 for row 212
# Shortest path length: 1.828 for row 213
# Shortest path length: 1.828 for row 214
# Shortest path length: 3.328 for row 215
# Shortest path length: 41.865 for row 216
# Shortest path length: 32.758 for row 217
# Shortest path length: 45.506 for row 218
# Shortest path length: 10.53 for row 219
# Shortest path length: 24.978 for row 220
# Shortest path length: 28.775 for row 221
# Shortest path length: 4.082 for row 222
# Shortest path length: 22.874 for row 223
# Shortest path length: 7.337 for row 224
# Shortest path length: 7.95 for row 225
# Shortest path length: 10.516 for row 226
# Shortest path length: 6.556 for row 227
# Shortest path length: 23.789 for row 228
# Shortest path length: 22.69 for row 229
# Shortest path length: 22.182 for row 230
# Shortest path length: 9.238 for row 231
# Shortest path length: 22.869 for row 232
# Shortest path length: 21.374 for row 233
# Shortest path length: 35.043 for row 234
# Shortest path length: 7.854 for row 235
# Shortest path length: 7.448 for row 236
# Shortest path length: 31.924 for row 237
# Shortest path length: 8.374 for row 238
# Shortest path length: 7.523 for row 239
# Shortest path length: 37.794 for row 240
# Shortest path length: 20.422 for row 241
# Shortest path length: 19.607 for row 242
# Shortest path length: 0.869 for row 243
# Shortest path length: 35.73 for row 244
# Shortest path length: 28.82 for row 245
# Shortest path length: 22.206 for row 246
# Shortest path length: 22.935 for row 247
# Shortest path length: 3.411 for row 248
# Shortest path length: 13.21 for row 249
# Shortest path length: 10.901 for row 250
# Shortest path length: 5.533 for row 251
# Shortest path length: 12.765 for row 252
# Shortest path length: 23.013 for row 253
# Shortest path length: 11.332 for row 254
# Shortest path length: 21.718 for row 255
# Shortest path length: 22.694 for row 256
# Shortest path length: 5.048 for row 257
# Shortest path length: 5.572 for row 258
# Shortest path length: 8.197 for row 259
# Shortest path length: 14.561 for row 260
# Shortest path length: 13.379 for row 261
# Shortest path length: 13.379 for row 262
# Shortest path length: 13.379 for row 263
# Shortest path length: 8.707 for row 264
# Shortest path length: 7.401 for row 265
# Shortest path length: 10.672 for row 266
# Shortest path length: 7.715 for row 267
# Shortest path length: 16.213 for row 268
# Shortest path length: 17.442 for row 269
# Shortest path length: 16.888 for row 270
# Shortest path length: 28.646 for row 271
# Shortest path length: 27.89 for row 272
# Shortest path length: 27.89 for row 273
# Shortest path length: 28.322 for row 274
# Shortest path length: 28.322 for row 275
# Shortest path length: 29.916 for row 276
# Shortest path length: 29.916 for row 277
# Shortest path length: 34.715 for row 278
# Shortest path length: 18.095 for row 279
# Shortest path length: 6.475 for row 280
# Shortest path length: 12.304 for row 281
# Shortest path length: 9.921 for row 282
# Shortest path length: 19.062 for row 283
# Shortest path length: 20.975 for row 284
# Shortest path length: 16.939 for row 285
# Shortest path length: 16.939 for row 286
# Shortest path length: 10.048 for row 287
# Shortest path length: 12.401 for row 288
# Shortest path length: 1.266 for row 289
# Shortest path length: 18.194 for row 290
# Shortest path length: 12.022 for row 291
# Shortest path length: 16.939 for row 292
# Shortest path length: 8.248 for row 293
# Shortest path length: 9.431 for row 294
# Shortest path length: 9.229 for row 295
# Shortest path length: 9.479 for row 296
# Shortest path length: 9.133 for row 297
# Shortest path length: 8.248 for row 298
# Shortest path length: 5.337 for row 299
# Shortest path length: 6.915 for row 300
# Shortest path length: 8.27 for row 301
# Shortest path length: 6.712 for row 302
# Shortest path length: 10.006 for row 303
# Shortest path length: 5.702 for row 304
# Shortest path length: 5.748 for row 305
# Shortest path length: 5.702 for row 306
# Shortest path length: 10.558 for row 307
# Shortest path length: 10.558 for row 308
# Shortest path length: 10.7 for row 309
# Shortest path length: 10.7 for row 310
# Shortest path length: 6.897 for row 311
# Shortest path length: 7.599 for row 312
# Shortest path length: 5.237 for row 313
# Shortest path length: 6.842 for row 314
# Shortest path length: 20.975 for row 315
# Shortest path length: 18.795 for row 316
# Shortest path length: 5.286 for row 317
# Shortest path length: 5.561 for row 318
# Shortest path length: 5.925 for row 319
# Shortest path length: 10.99 for row 320
# Shortest path length: 5.478 for row 321
# Shortest path length: 5.039 for row 322
# Shortest path length: 6.376 for row 323
# Shortest path length: 20.439 for row 324
# Shortest path length: 10.891 for row 325
# Shortest path length: 7.977 for row 326
# Shortest path length: 7.94 for row 327
# Shortest path length: 10.38 for row 328
# Shortest path length: 16.595 for row 329
# Shortest path length: 16.595 for row 330
# Shortest path length: 6.637 for row 331
# Shortest path length: 7.616 for row 332
# Shortest path length: 16.595 for row 333
# Shortest path length: 18.175 for row 334
# Shortest path length: 19.784 for row 335
# Shortest path length: 19.784 for row 336
# Shortest path length: 18.657 for row 337
# Shortest path length: 9.843 for row 338
# Shortest path length: 18.175 for row 339
# Shortest path length: 13.302 for row 340
# Shortest path length: 14.468 for row 341
# Shortest path length: 14.468 for row 342
# Shortest path length: 14.468 for row 343
# Shortest path length: 10.49 for row 344
# Shortest path length: 7.496 for row 345
# Shortest path length: 6.541 for row 346
# Shortest path length: 15.534 for row 347
# Shortest path length: 14.381 for row 348
# Shortest path length: 11.37 for row 349
# Shortest path length: 9.121 for row 350
# Shortest path length: 12.472 for row 351
# Shortest path length: 8.502 for row 352
# Shortest path length: 12.641 for row 353
# Shortest path length: 14.617 for row 354
# Shortest path length: 12.023 for row 355
# Shortest path length: 12.023 for row 356
# Shortest path length: 4.108 for row 357
# Shortest path length: 6.46 for row 358
# Shortest path length: 4.95 for row 359
# Shortest path length: 5.166 for row 360
# Shortest path length: 5.246 for row 361
# Shortest path length: 4.896 for row 362
# Shortest path length: 4.793 for row 363
# Shortest path length: 4.837 for row 364
# Shortest path length: 5.285 for row 365
# Shortest path length: 11.35 for row 366
# Shortest path length: 10.301 for row 367
# Shortest path length: 5.99 for row 368
# Shortest path length: 6.115 for row 369
# Shortest path length: 10.132 for row 370
# Shortest path length: 6.665 for row 371
# Shortest path length: 4.805 for row 372
# Shortest path length: 3.211 for row 373
# Shortest path length: 4.046 for row 374
# Shortest path length: 4.306 for row 375
# Shortest path length: 5.769 for row 376
# Shortest path length: 3.701 for row 377
# Shortest path length: 7.609 for row 378
# Shortest path length: 7.609 for row 379
# Shortest path length: 27.302 for row 380
# Shortest path length: 6.752 for row 381
# Shortest path length: 7.066 for row 382
# Shortest path length: 7.066 for row 383
# Shortest path length: 7.066 for row 384
# Shortest path length: 6.419 for row 385
# Shortest path length: 2.296 for row 386
# Shortest path length: 6.419 for row 387
# Shortest path length: 2.747 for row 388
# Shortest path length: 11.357 for row 389
# Shortest path length: 22.85 for row 390
# Shortest path length: 10.848 for row 391
# Shortest path length: 16.885 for row 392
# Shortest path length: 1.75 for row 393
# Shortest path length: 0.561 for row 394
# Shortest path length: 4294967.295 for row 395
# Shortest path length: 4.68 for row 396
# Shortest path length: 4.405 for row 397
# Shortest path length: 3.796 for row 398
# Shortest path length: 4.841 for row 399
# Shortest path length: 4.841 for row 400
# Shortest path length: 4.619 for row 401
# Shortest path length: 27.23 for row 402
# Shortest path length: 3.601 for row 403
# Shortest path length: 3.946 for row 404
# Shortest path length: 3.329 for row 405
# Shortest path length: 29.8 for row 406
# Shortest path length: 3.329 for row 407
# Shortest path length: 9.47 for row 408
# Shortest path length: 36.036 for row 409
# Shortest path length: 19.16 for row 410
# Shortest path length: 4.176 for row 411
# Shortest path length: 13.244 for row 412
# Shortest path length: 17.871 for row 413
# Shortest path length: 34.594 for row 414
# Shortest path length: 13.948 for row 415
# Shortest path length: 13.917 for row 416
# Shortest path length: 3.888 for row 417
# Shortest path length: 2.624 for row 418
# Shortest path length: 3.047 for row 419
# Shortest path length: 4.569 for row 420
# Shortest path length: 5.177 for row 421
# Shortest path length: 5.062 for row 422
# Shortest path length: 5.177 for row 423
# Shortest path length: 4.667 for row 424
# Shortest path length: 19.479 for row 425
# Shortest path length: 4.86 for row 426
# Shortest path length: 14.866 for row 427
# Shortest path length: 10.382 for row 428
# Shortest path length: 10.798 for row 429
# Shortest path length: 10.382 for row 430
# Shortest path length: 6.683 for row 431
# Shortest path length: 10.183 for row 432
# Shortest path length: 15.648 for row 433
# Shortest path length: 10.301 for row 434
# Shortest path length: 20.618 for row 435
# Shortest path length: 11.852 for row 436
# Shortest path length: 28.751 for row 437
# Shortest path length: 6.665 for row 438
# Shortest path length: 7.071 for row 439
# Shortest path length: 7.071 for row 440
# Shortest path length: 6.567 for row 441
# Shortest path length: 6.701 for row 442
# Shortest path length: 6.382 for row 443
# Shortest path length: 25.336 for row 444
# Shortest path length: 22.391 for row 445
# Shortest path length: 29.772 for row 446
# Shortest path length: 29.772 for row 447
# Shortest path length: 29.297 for row 448
# Shortest path length: 27.161 for row 449
# Shortest path length: 4.356 for row 450
# Shortest path length: 7.604 for row 451
# Shortest path length: 14.085 for row 452
# Shortest path length: 24.135 for row 453
# Shortest path length: 8.087 for row 454
# Shortest path length: 25.455 for row 455
# Shortest path length: 11.35 for row 456
# Shortest path length: 11.35 for row 457
# Shortest path length: 29.772 for row 458
# Shortest path length: 28.747 for row 459
# Shortest path length: 27.23 for row 460
# Shortest path length: 29.763 for row 461
# Shortest path length: 21.803 for row 462
# Shortest path length: 26.059 for row 463
# Shortest path length: 26.059 for row 464
# Shortest path length: 18.399 for row 465
# Shortest path length: 5.118 for row 466
# Shortest path length: 10.397 for row 467
# Shortest path length: 32.827 for row 468
# Shortest path length: 29.772 for row 469
# Shortest path length: 2.951 for row 470
# Shortest path length: 30.696 for row 471
# Shortest path length: 4.097 for row 472
# Shortest path length: 26.113 for row 473
# Shortest path length: 27.964 for row 474
# Shortest path length: 1.266 for row 475
# Shortest path length: 29.162 for row 476
# Shortest path length: 29.916 for row 477
# Shortest path length: 29.36 for row 478
# Shortest path length: 26.962 for row 479
# Shortest path length: 21.438 for row 480
# Shortest path length: 24.71 for row 481
# Shortest path length: 26.737 for row 482
# Shortest path length: 34.799 for row 483
# Shortest path length: 36.805 for row 484
# Shortest path length: 4.844 for row 485
# Shortest path length: 67.14 for row 486
# Shortest path length: 12.545 for row 487
# Shortest path length: 51.558 for row 488
# Shortest path length: 10.879 for row 489
# Shortest path length: 10.24 for row 490
# Shortest path length: 7.465 for row 491
# Shortest path length: 4.351 for row 492
# Shortest path length: 4.644 for row 493
# Shortest path length: 67.317 for row 494
# Shortest path length: 3.88 for row 495
# Shortest path length: 70.284 for row 496
# Shortest path length: 10.266 for row 497
# Shortest path length: 67.465 for row 498
# Shortest path length: 15.771 for row 499
# Shortest path length: 61.763 for row 500
# Shortest path length: 52.596 for row 501
# Shortest path length: 52.596 for row 502
# Shortest path length: 20.052 for row 503
# Shortest path length: 18.245 for row 504
# Shortest path length: 39.98 for row 505
# Shortest path length: 14.963 for row 506
# Shortest path length: 17.447 for row 507
# Shortest path length: 39.96 for row 508
# Shortest path length: 44.707 for row 509
# Shortest path length: 36.768 for row 510
# Shortest path length: 19.238 for row 511
# Shortest path length: 29.727 for row 512
# Shortest path length: 20.095 for row 513
# Shortest path length: 25.79 for row 514
# Shortest path length: 20.979 for row 515
# Shortest path length: 7.35 for row 516
# Shortest path length: 7.35 for row 517
# Shortest path length: 5.012 for row 518
# Shortest path length: 5.012 for row 519
# Shortest path length: 87.293 for row 520
# Shortest path length: 10.801 for row 521
# Shortest path length: 94.229 for row 522
# Shortest path length: 78.701 for row 523
# Shortest path length: 17.654 for row 524
# Shortest path length: 94.229 for row 525
# Shortest path length: 19.98 for row 526
# Shortest path length: 55.305 for row 527
# Shortest path length: 19.7 for row 528
# Shortest path length: 18.62 for row 529
# Shortest path length: 87.293 for row 530
# Shortest path length: 75.292 for row 531
# Shortest path length: 30.026 for row 532
# Shortest path length: 30.737 for row 533
# Shortest path length: 8.822 for row 534
# Shortest path length: 8.822 for row 535
# Shortest path length: 9.889 for row 536
# Shortest path length: 21.115 for row 537
# Shortest path length: 12.094 for row 538
# Shortest path length: 12.094 for row 539
# Shortest path length: 9.889 for row 540
# Shortest path length: 12.094 for row 541
# Shortest path length: 9.889 for row 542
# Shortest path length: 9.889 for row 543
# Shortest path length: 10.694 for row 544
# Shortest path length: 10.694 for row 545
# Shortest path length: 16.235 for row 546
# Shortest path length: 2.371 for row 547
# Shortest path length: 45.061 for row 548
# Shortest path length: 45.061 for row 549
# Shortest path length: 39.932 for row 550
# Shortest path length: 90.898 for row 551
# Shortest path length: 13.314 for row 552
# Shortest path length: 47.605 for row 553
# Shortest path length: 18.701 for row 554
# Shortest path length: 12.078 for row 555
# Shortest path length: 9.957 for row 556
# Shortest path length: 10.574 for row 557
# Shortest path length: 10.574 for row 558
# Shortest path length: 51.541 for row 559
# Shortest path length: 55.899 for row 560
# Shortest path length: 12.941 for row 561
# Shortest path length: 32.973 for row 562
# Shortest path length: 8.872 for row 563
# Shortest path length: 83.76 for row 564
# Shortest path length: 103.237 for row 565
# Shortest path length: 118.193 for row 566
# Shortest path length: 102.275 for row 567
# Shortest path length: 97.171 for row 568
# Shortest path length: 37.978 for row 569
# Shortest path length: 9.957 for row 570
# Shortest path length: 11.555 for row 571
# Shortest path length: 15.156 for row 572
# Shortest path length: 32.478 for row 573
# Shortest path length: 52.395 for row 574
# Shortest path length: 71.08 for row 575
# Shortest path length: 48.106 for row 576
# Shortest path length: 100.143 for row 577
# Shortest path length: 93.551 for row 578
# Shortest path length: 101.288 for row 579
# Shortest path length: 21.053 for row 580
# Shortest path length: 9.123 for row 581
# Shortest path length: 8.385 for row 582
# Shortest path length: 14.694 for row 583
# Shortest path length: 8.73 for row 584
# Shortest path length: 6.202 for row 585
# Shortest path length: 12.207 for row 586
# Shortest path length: 16.443 for row 587
# Shortest path length: 11.988 for row 588
# Shortest path length: 12.851 for row 589
# Shortest path length: 36.15 for row 590
# Shortest path length: 14.657 for row 591
# Shortest path length: 16.861 for row 592
# Shortest path length: 30.67 for row 593
# Shortest path length: 13.557 for row 594
# Shortest path length: 13.712 for row 595
# Shortest path length: 15.163 for row 596
# Shortest path length: 15.163 for row 597
# Shortest path length: 13.712 for row 598
# Shortest path length: 16.804 for row 599
# Shortest path length: 9.994 for row 600
# Shortest path length: 4.971 for row 601
# Shortest path length: 5.799 for row 602
# Shortest path length: 13.712 for row 603
# Shortest path length: 13.712 for row 604
# Shortest path length: 15.486 for row 605
# Shortest path length: 54.227 for row 606
# Shortest path length: 37.865 for row 607
# Shortest path length: 36.623 for row 608
# Shortest path length: 54.764 for row 609
# Shortest path length: 48.715 for row 610
# Shortest path length: 54.667 for row 611
# Shortest path length: 14.598 for row 612
# Shortest path length: 9.218 for row 613
# Shortest path length: 16.443 for row 614
# Shortest path length: 27.83 for row 615
# Shortest path length: 16.443 for row 616
# Shortest path length: 14.598 for row 617
# Shortest path length: 16.443 for row 618
# Shortest path length: 11.685 for row 619
# Shortest path length: 11.685 for row 620
# Shortest path length: 21.942 for row 621
# Shortest path length: 8.957 for row 622
# Shortest path length: 12.839 for row 623
# Shortest path length: 22.94 for row 624
# Shortest path length: 20.014 for row 625
# Shortest path length: 18.88 for row 626
# Shortest path length: 23.021 for row 627
# Shortest path length: 20.35 for row 628
# Shortest path length: 20.166 for row 629
# Shortest path length: 42.106 for row 630
# Shortest path length: 20.651 for row 631
# Shortest path length: 20.651 for row 632
# Shortest path length: 26.887 for row 633
# Shortest path length: 39.322 for row 634
# Shortest path length: 19.526 for row 635
# Shortest path length: 18.531 for row 636
# Shortest path length: 17.044 for row 637
# Shortest path length: 7.44 for row 638
# Shortest path length: 6.799 for row 639
# Shortest path length: 50.899 for row 640
# Shortest path length: 6.799 for row 641
# Shortest path length: 68.063 for row 642
# Shortest path length: 8.583 for row 643
# Shortest path length: 7.132 for row 644
# Shortest path length: 16.523 for row 645
# Shortest path length: 9.01 for row 646
# Shortest path length: 10.095 for row 647
# Shortest path length: 11.866 for row 648
# Shortest path length: 11.866 for row 649
# Shortest path length: 13.571 for row 650
# Shortest path length: 13.571 for row 651
# Shortest path length: 15.799 for row 652
# Shortest path length: 14.558 for row 653
# Shortest path length: 9.01 for row 654
# Shortest path length: 10.934 for row 655
# Shortest path length: 13.555 for row 656
# Shortest path length: 18.798 for row 657
# Shortest path length: 6.884 for row 658
# Shortest path length: 17.386 for row 659
# Shortest path length: 20.671 for row 660
# Shortest path length: 20.429 for row 661
# Shortest path length: 22.915 for row 662
# Shortest path length: 12.686 for row 663
# Shortest path length: 47.497 for row 664
# Shortest path length: 12.275 for row 665
# Shortest path length: 70.369 for row 666
# Shortest path length: 19.471 for row 667
# Shortest path length: 4.608 for row 668
# Shortest path length: 17.588 for row 669
# Shortest path length: 3.398 for row 670
# Shortest path length: 17.628 for row 671
# Shortest path length: 0.737 for row 672
# Shortest path length: 17.628 for row 673
# Shortest path length: 6.646 for row 674
# Shortest path length: 6.493 for row 675
# Shortest path length: 7.389 for row 676
# Shortest path length: 4.608 for row 677
# Shortest path length: 3.075 for row 678
# Shortest path length: 24.247 for row 679
# Shortest path length: 20.673 for row 680
# Shortest path length: 4294967.295 for row 681
# Shortest path length: 18.417 for row 682
# Shortest path length: 4294967.295 for row 683
# Shortest path length: 3.776 for row 684
# Shortest path length: 17.567 for row 685
# Shortest path length: 4294967.295 for row 686
# Shortest path length: 8.473 for row 687
# Shortest path length: 4.446 for row 688
# Shortest path length: 4.446 for row 689
# Shortest path length: 15.774 for row 690
# Shortest path length: 13.937 for row 691
# Shortest path length: 7.211 for row 692
# Shortest path length: 4.658 for row 693
# Shortest path length: 5.723 for row 694
# Shortest path length: 14.62 for row 695
# Shortest path length: 12.82 for row 696
# Shortest path length: 16.69 for row 697
# Shortest path length: 6.503 for row 698
# Shortest path length: 10.605 for row 699
# Shortest path length: 7.563 for row 700
# Shortest path length: 29.092 for row 701
# Shortest path length: 29.654 for row 702
# Shortest path length: 15.98 for row 703
# Shortest path length: 6.86 for row 704
# Shortest path length: 23.837 for row 705
# Shortest path length: 23.567 for row 706
# Shortest path length: 7.413 for row 707
# Shortest path length: 35.918 for row 708
# Shortest path length: 6.973 for row 709
# Shortest path length: 6.59 for row 710
# Shortest path length: 7.134 for row 711
# Shortest path length: 4.218 for row 712
# Shortest path length: 5.622 for row 713
# Shortest path length: 5.57 for row 714
# Shortest path length: 4.575 for row 715
# Shortest path length: 5.089 for row 716
# Shortest path length: 9.309 for row 717
# Shortest path length: 29.552 for row 718
# Shortest path length: 21.787 for row 719
# Shortest path length: 23.417 for row 720
# Shortest path length: 27.02 for row 721
# Shortest path length: 23.417 for row 722
# Shortest path length: 24.808 for row 723
# Shortest path length: 28.966 for row 724
# Shortest path length: 28.684 for row 725
# Shortest path length: 34.772 for row 726
# Shortest path length: 50.473 for row 727
# Shortest path length: 6.773 for row 728
# Shortest path length: 6.973 for row 729
# Shortest path length: 25.982 for row 730
# Shortest path length: 24.746 for row 731
# Shortest path length: 24.746 for row 732
# Shortest path length: 29.588 for row 733
# Shortest path length: 49.62 for row 734
# Shortest path length: 49.62 for row 735
# Shortest path length: 30.313 for row 736
# Shortest path length: 30.904 for row 737
# Shortest path length: 14.625 for row 738
# Shortest path length: 34.296 for row 739
# Shortest path length: 34.296 for row 740
# Shortest path length: 23.417 for row 741
# Shortest path length: 26.824 for row 742
# Shortest path length: 24.338 for row 743
# Shortest path length: 26.824 for row 744
# Shortest path length: 34.296 for row 745
# Shortest path length: 23.228 for row 746
# Shortest path length: 5.561 for row 747
# Shortest path length: 6.409 for row 748
# Shortest path length: 25.848 for row 749
# Shortest path length: 53.65 for row 750
# Shortest path length: 32.542 for row 751
# Shortest path length: 6.893 for row 752
# Shortest path length: 45.876 for row 753
# Shortest path length: 20.532 for row 754
# Shortest path length: 30.904 for row 755
# Shortest path length: 11.301 for row 756
# Shortest path length: 15.534 for row 757
# Shortest path length: 18.114 for row 758
# Shortest path length: 12.711 for row 759
# Shortest path length: 12.711 for row 760
# Shortest path length: 13.274 for row 761
# Shortest path length: 17.909 for row 762
# Shortest path length: 14.821 for row 763
# Shortest path length: 14.821 for row 764
# Shortest path length: 14.821 for row 765
# Shortest path length: 15.878 for row 766
# Shortest path length: 13.917 for row 767
# Shortest path length: 22.702 for row 768
# Shortest path length: 24.167 for row 769
# Shortest path length: 20.362 for row 770
# Shortest path length: 22.854 for row 771
# Shortest path length: 22.615 for row 772
# Shortest path length: 13.156 for row 773
# Shortest path length: 14.831 for row 774
# Shortest path length: 22.854 for row 775
# Shortest path length: 34.157 for row 776
# Shortest path length: 29.298 for row 777
# Shortest path length: 25.403 for row 778
# Shortest path length: 22.854 for row 779
# Shortest path length: 21.898 for row 780
# Shortest path length: 40.304 for row 781
# Shortest path length: 65.647 for row 782
# Shortest path length: 50.679 for row 783
# Shortest path length: 90.287 for row 784
# Shortest path length: 44.605 for row 785
# Shortest path length: 50.679 for row 786
# Shortest path length: 54.387 for row 787
# Shortest path length: 45.918 for row 788
# Shortest path length: 41.44 for row 789
# Shortest path length: 43.38 for row 790
# Shortest path length: 40.208 for row 791
# Shortest path length: 10.282 for row 792
# Shortest path length: 39.482 for row 793
# Shortest path length: 39.549 for row 794
# Shortest path length: 39.012 for row 795
# Shortest path length: 40.052 for row 796
# Shortest path length: 40.304 for row 797
# Shortest path length: 45.01 for row 798
# Shortest path length: 43.13 for row 799
# Shortest path length: 45.208 for row 800
# Shortest path length: 42.839 for row 801
# Shortest path length: 39.549 for row 802
# Shortest path length: 40.208 for row 803
# Shortest path length: 38.814 for row 804
# Shortest path length: 38.814 for row 805
# Shortest path length: 52.643 for row 806
# Shortest path length: 67.824 for row 807
# Shortest path length: 62.806 for row 808
# Shortest path length: 90.287 for row 809
# Shortest path length: 67.505 for row 810
# Shortest path length: 39.012 for row 811
# Shortest path length: 49.492 for row 812
# Shortest path length: 24.601 for row 813
# Shortest path length: 24.601 for row 814
# Shortest path length: 24.601 for row 815
# Shortest path length: 24.041 for row 816
# Shortest path length: 23.902 for row 817
# Shortest path length: 30.136 for row 818
# Shortest path length: 51.298 for row 819
# Shortest path length: 25.718 for row 820
# Shortest path length: 21.809 for row 821
# Shortest path length: 21.809 for row 822
# Shortest path length: 21.939 for row 823
# Shortest path length: 21.939 for row 824
# Shortest path length: 21.939 for row 825
# Shortest path length: 25.879 for row 826
# Shortest path length: 25.285 for row 827
# Shortest path length: 26.212 for row 828
# Shortest path length: 30.068 for row 829
# Shortest path length: 27.949 for row 830
# Shortest path length: 26.212 for row 831
# Shortest path length: 26.62 for row 832
# Shortest path length: 26.99 for row 833
# Shortest path length: 26.343 for row 834
# Shortest path length: 26.449 for row 835
# Shortest path length: 27.472 for row 836
# Shortest path length: 27.472 for row 837
# Shortest path length: 27.038 for row 838
# Shortest path length: 27.832 for row 839
# Shortest path length: 28.259 for row 840
# Shortest path length: 23.084 for row 841
# Shortest path length: 23.367 for row 842
# Shortest path length: 27.425 for row 843
# Shortest path length: 27.038 for row 844
# Shortest path length: 27.748 for row 845
# Shortest path length: 27.164 for row 846
# Shortest path length: 27.191 for row 847
# Shortest path length: 27.877 for row 848
# Shortest path length: 24.618 for row 849
# Shortest path length: 25.18 for row 850
# Shortest path length: 25.18 for row 851
# Shortest path length: 25.626 for row 852
# Shortest path length: 25.497 for row 853
# Shortest path length: 25.879 for row 854
# Shortest path length: 25.879 for row 855
# Shortest path length: 26.343 for row 856
# Shortest path length: 26.343 for row 857
# Shortest path length: 35.836 for row 858
# Shortest path length: 48.919 for row 859
# Shortest path length: 54.324 for row 860
# Shortest path length: 45.787 for row 861
# Shortest path length: 48.278 for row 862
# Shortest path length: 25.003 for row 863
# Shortest path length: 26.425 for row 864
# Shortest path length: 25.285 for row 865
# Shortest path length: 24.148 for row 866
# Shortest path length: 26.203 for row 867
# Shortest path length: 25.232 for row 868
# Shortest path length: 24.117 for row 869
# Shortest path length: 21.939 for row 870
# Shortest path length: 23.46 for row 871
# Shortest path length: 22.072 for row 872
# Shortest path length: 24.584 for row 873
# Shortest path length: 23.46 for row 874
# Shortest path length: 23.46 for row 875
# Shortest path length: 22.97 for row 876
# Shortest path length: 21.939 for row 877
# Shortest path length: 21.939 for row 878
# Shortest path length: 22.97 for row 879
# Shortest path length: 22.97 for row 880
# Shortest path length: 22.405 for row 881
# Shortest path length: 22.405 for row 882
# Shortest path length: 22.405 for row 883
# Shortest path length: 21.96 for row 884
# Shortest path length: 22.97 for row 885
# Shortest path length: 22.587 for row 886
# Shortest path length: 23.358 for row 887
# Shortest path length: 23.008 for row 888
# Shortest path length: 23.008 for row 889
# Shortest path length: 23.501 for row 890
# Shortest path length: 24.29 for row 891
# Shortest path length: 24.618 for row 892
# Shortest path length: 24.618 for row 893
# Shortest path length: 24.618 for row 894
# Shortest path length: 24.41 for row 895
# Shortest path length: 32.574 for row 896
# Shortest path length: 59.14 for row 897
# Shortest path length: 25.852 for row 898
# Shortest path length: 24.041 for row 899
# Shortest path length: 25.879 for row 900
# Shortest path length: 30.965 for row 901
# Shortest path length: 24.29 for row 902
# Shortest path length: 24.041 for row 903
# Shortest path length: 30.074 for row 904
# Shortest path length: 14.799 for row 905
# Shortest path length: 64.069 for row 906
# Shortest path length: 3.154 for row 907
# Shortest path length: 3.154 for row 908
# Shortest path length: 21.404 for row 909
# Shortest path length: 16.356 for row 910
# Shortest path length: 33.025 for row 911
# Shortest path length: 33.025 for row 912
# Shortest path length: 6.089 for row 913
# Shortest path length: 3.601 for row 914
# Shortest path length: 4.756 for row 915
# Shortest path length: 27.431 for row 916
# Shortest path length: 30.862 for row 917
# Shortest path length: 6.319 for row 918
# Shortest path length: 6.509 for row 919
# Shortest path length: 6.509 for row 920
# Shortest path length: 3.501 for row 921
# Shortest path length: 28.911 for row 922
# Shortest path length: 27.813 for row 923
# Shortest path length: 29.562 for row 924
# Shortest path length: 29.654 for row 925
# Shortest path length: 26.784 for row 926
# Shortest path length: 26.747 for row 927
# Shortest path length: 21.432 for row 928
# Shortest path length: 27.123 for row 929
# Shortest path length: 34.603 for row 930
# Shortest path length: 67.038 for row 931
# Shortest path length: 3.501 for row 932
# Shortest path length: 2.97 for row 933
# Shortest path length: 2.97 for row 934
# Shortest path length: 2.751 for row 935
# Shortest path length: 3.501 for row 936
# Shortest path length: 4.672 for row 937
# Shortest path length: 11.127 for row 938
# Shortest path length: 7.521 for row 939
# Shortest path length: 20.379 for row 940
# Shortest path length: 18.869 for row 941
# Shortest path length: 7.733 for row 942
# Shortest path length: 14.969 for row 943
# Shortest path length: 0.747 for row 944
# Shortest path length: 21.416 for row 945
# Shortest path length: 18.869 for row 946
# Shortest path length: 21.335 for row 947
# Shortest path length: 19.225 for row 948
# Shortest path length: 30.711 for row 949
# Shortest path length: 26.81 for row 950
# Shortest path length: 11.5 for row 951
# Shortest path length: 3.062 for row 952
# Shortest path length: 2.693 for row 953
# Shortest path length: 0.3 for row 954
# Shortest path length: 2.72 for row 955
# Shortest path length: 2.775 for row 956
# Shortest path length: 2.97 for row 957
# Shortest path length: 2.72 for row 958
# Shortest path length: 2.579 for row 959
# Shortest path length: 2.175 for row 960
# Shortest path length: 1.889 for row 961
# Shortest path length: 2.576 for row 962
# Shortest path length: 2.354 for row 963
# Shortest path length: 2.075 for row 964
# Shortest path length: 12.092 for row 965
# Shortest path length: 12.085 for row 966
# Shortest path length: 13.206 for row 967
# Shortest path length: 18.752 for row 968
# Shortest path length: 23.207 for row 969
# Shortest path length: 1.48 for row 970
# Shortest path length: 1.11 for row 971
# Shortest path length: 1.238 for row 972
# Shortest path length: 1.238 for row 973
# Shortest path length: 1.48 for row 974
# Shortest path length: 2.175 for row 975
# Shortest path length: 1.48 for row 976
# Shortest path length: 2.075 for row 977
# Shortest path length: 4.672 for row 978
# Shortest path length: 3.136 for row 979
# Shortest path length: 24.633 for row 980
# Shortest path length: 38.751 for row 981
# Shortest path length: 33.11 for row 982
# Shortest path length: 33.11 for row 983
# Shortest path length: 32.714 for row 984
# Shortest path length: 26.843 for row 985
# Shortest path length: 40.198 for row 986
# Shortest path length: 58.609 for row 987
# Shortest path length: 59.699 for row 988
# Shortest path length: 64.545 for row 989
# Shortest path length: 64.915 for row 990
# Shortest path length: 26.747 for row 991
# Shortest path length: 26.747 for row 992
# Shortest path length: 12.315 for row 993
# Shortest path length: 3.062 for row 994
# Shortest path length: 7.282 for row 995
# Shortest path length: 7.282 for row 996
# Shortest path length: 7.282 for row 997
# Shortest path length: 70.996 for row 998
# Shortest path length: 49.435 for row 999
# Shortest path length: 52.336 for row 1000
# Shortest path length: 51.866 for row 1001
# Shortest path length: 46.964 for row 1002
# Shortest path length: 29.552 for row 1003
# Shortest path length: 40.354 for row 1004
# Shortest path length: 17.48 for row 1005
# Shortest path length: 8.842 for row 1006
# Shortest path length: 42.471 for row 1007
# Shortest path length: 42.984 for row 1008
# Shortest path length: 32.386 for row 1009
# Shortest path length: 38.401 for row 1010
# Shortest path length: 39.607 for row 1011
# Shortest path length: 38.486 for row 1012
# Shortest path length: 19.935 for row 1013
# Shortest path length: 26.73 for row 1014
# Shortest path length: 38.656 for row 1015
# Shortest path length: 38.656 for row 1016
# Shortest path length: 36.142 for row 1017
# Shortest path length: 44.685 for row 1018
# Shortest path length: 27.319 for row 1019
# Shortest path length: 10.361 for row 1020
# Shortest path length: 13.651 for row 1021
# Shortest path length: 8.842 for row 1022
# Shortest path length: 29.552 for row 1023
# Shortest path length: 49.91 for row 1024
# Shortest path length: 45.529 for row 1025
# Shortest path length: 64.797 for row 1026
# Shortest path length: 71.39 for row 1027
# Shortest path length: 11.036 for row 1028
# Shortest path length: 16.69 for row 1029
# Shortest path length: 9.131 for row 1030
# Shortest path length: 14.603 for row 1031
# Shortest path length: 14.603 for row 1032
# Shortest path length: 14.603 for row 1033
# Shortest path length: 14.603 for row 1034
# Shortest path length: 102.056 for row 1035
# Shortest path length: 94.445 for row 1036
# Shortest path length: 102.444 for row 1037
# Shortest path length: 107.612 for row 1038
# Shortest path length: 107.612 for row 1039
# Shortest path length: 107.612 for row 1040
# Shortest path length: 105.887 for row 1041
# Shortest path length: 105.881 for row 1042
# Shortest path length: 101.943 for row 1043
# Shortest path length: 101.943 for row 1044
# Shortest path length: 104.452 for row 1045
# Shortest path length: 105.195 for row 1046
# Shortest path length: 59.767 for row 1047
# Shortest path length: 104.384 for row 1048
# Shortest path length: 105.917 for row 1049
# Shortest path length: 104.771 for row 1050
# Shortest path length: 107.333 for row 1051
# Shortest path length: 94.87 for row 1052
# Shortest path length: 110.788 for row 1053
# Shortest path length: 114.64 for row 1054
# Shortest path length: 114.64 for row 1055
# Shortest path length: 116.886 for row 1056
# Shortest path length: 124.889 for row 1057
# Shortest path length: 119.577 for row 1058
# Shortest path length: 110.44 for row 1059
# Shortest path length: 108.216 for row 1060
# Shortest path length: 110.627 for row 1061
# Shortest path length: 104.967 for row 1062
# Shortest path length: 100.878 for row 1063
# Shortest path length: 100.295 for row 1064
# Shortest path length: 96.534 for row 1065
# Shortest path length: 105.581 for row 1066
# Shortest path length: 106.781 for row 1067
# Shortest path length: 98.527 for row 1068
# Shortest path length: 100.755 for row 1069
# Shortest path length: 113.685 for row 1070
# Shortest path length: 99.095 for row 1071
# Shortest path length: 109.119 for row 1072
# Shortest path length: 104.196 for row 1073
# Shortest path length: 94.058 for row 1074
# Shortest path length: 98.607 for row 1075
# Shortest path length: 101.721 for row 1076
# Shortest path length: 112.888 for row 1077
# Shortest path length: 106.203 for row 1078
# Shortest path length: 112.936 for row 1079
# Shortest path length: 110.35 for row 1080
# Shortest path length: 107.612 for row 1081
# Shortest path length: 4294967.295 for row 1082
# Shortest path length: 4294967.295 for row 1083
# Shortest path length: 4294967.295 for row 1084
# Shortest path length: 53.463 for row 1085
# Shortest path length: 4294967.295 for row 1086
# Shortest path length: 4294967.295 for row 1087
# Shortest path length: 4294967.295 for row 1088
# Shortest path length: 61.421 for row 1089
# Shortest path length: 42.445 for row 1090
# Shortest path length: 30.337 for row 1091
# Shortest path length: 28.131 for row 1092
# Shortest path length: 34.661 for row 1093
# Shortest path length: 22.653 for row 1094
# Shortest path length: 3.4 for row 1095
# Shortest path length: 5.88 for row 1096
# Shortest path length: 4.842 for row 1097
# Shortest path length: 40.47 for row 1098
# Shortest path length: 17.941 for row 1099
# Shortest path length: 27.951 for row 1100
# Shortest path length: 35.798 for row 1101
# Shortest path length: 36.068 for row 1102
# Shortest path length: 37.125 for row 1103
# Shortest path length: 37.46 for row 1104
# Shortest path length: 4.552 for row 1105
# Shortest path length: 38.222 for row 1106
# Shortest path length: 1.903 for row 1107
# Shortest path length: 2.657 for row 1108
# Shortest path length: 22.154 for row 1109
# Shortest path length: 22.935 for row 1110
# Shortest path length: 2.976 for row 1111
# Shortest path length: 6.886 for row 1112
# Shortest path length: 2.657 for row 1113
# Shortest path length: 8.427 for row 1114
# Shortest path length: 38.48 for row 1115
# Shortest path length: 58.268 for row 1116
# Shortest path length: 61.23 for row 1117
# Shortest path length: 61.23 for row 1118
# Shortest path length: 61.135 for row 1119
# Shortest path length: 61.135 for row 1120
# Shortest path length: 72.54 for row 1121
# Shortest path length: 2.866 for row 1122
# Shortest path length: 5.794 for row 1123
# Shortest path length: 6.717 for row 1124
# Shortest path length: 6.717 for row 1125
# Shortest path length: 8.02 for row 1126
# Shortest path length: 7.483 for row 1127
# Shortest path length: 13.731 for row 1128
# Shortest path length: 7.943 for row 1129
# Shortest path length: 4.241 for row 1130
# Shortest path length: 3.146 for row 1131
# Shortest path length: 10.854 for row 1132
# Shortest path length: 13.099 for row 1133
# Shortest path length: 17.29 for row 1134
# Shortest path length: 13.024 for row 1135
# Shortest path length: 45.586 for row 1136
# Shortest path length: 18.84 for row 1137
# Shortest path length: 8.635 for row 1138
# Shortest path length: 10.214 for row 1139
# Shortest path length: 2.866 for row 1140
# Shortest path length: 19.049 for row 1141
# Shortest path length: 13.94 for row 1142
# Shortest path length: 14.277 for row 1143
# Shortest path length: 13.94 for row 1144
# Shortest path length: 19.382 for row 1145
# Shortest path length: 13.049 for row 1146
# Shortest path length: 16.925 for row 1147
# Shortest path length: 50.726 for row 1148
# Shortest path length: 49.182 for row 1149
# Shortest path length: 50.014 for row 1150
# Shortest path length: 47.553 for row 1151
# Shortest path length: 40.399 for row 1152
# Shortest path length: 51.299 for row 1153
# Shortest path length: 51.649 for row 1154
# Shortest path length: 51.747 for row 1155
# Shortest path length: 49.329 for row 1156
# Shortest path length: 50.17 for row 1157
# Shortest path length: 52.304 for row 1158
# Shortest path length: 49.235 for row 1159
# Shortest path length: 50.049 for row 1160
# Shortest path length: 52.02 for row 1161
# Shortest path length: 50.773 for row 1162
# Shortest path length: 52.304 for row 1163
# Shortest path length: 2.975 for row 1164
# Shortest path length: 24.359 for row 1165
# Shortest path length: 22.269 for row 1166
# Shortest path length: 3.041 for row 1167
# Shortest path length: 3.127 for row 1168
# Shortest path length: 4.669 for row 1169
# Shortest path length: 35.114 for row 1170
# Shortest path length: 35.114 for row 1171
# Shortest path length: 18.571 for row 1172
# Shortest path length: 27.918 for row 1173
# Shortest path length: 3.485 for row 1174
# Shortest path length: 4.251 for row 1175
# Shortest path length: 4.251 for row 1176
# Shortest path length: 4.753 for row 1177
# Shortest path length: 15.889 for row 1178
# ...
# Shortest path length: 21.753 for row 1235
# Shortest path length: 38.098 for row 1236
# Shortest path length: 24.984 for row 1237
# Shortest path length: 24.984 for row 1238
# Shortest path length: 50.077 for row 1239
# Shortest path length: 19.773 for row 1240
# Shortest path length: 31.507 for row 1241
# Shortest path length: 18.538 for row 1242
# Shortest path length: 18.841 for row 1243
# Shortest path length: 18.841 for row 1244
# Shortest path length: 18.462 for row 1245
# Shortest path length: 44.508 for row 1246
# Shortest path length: 46.001 for row 1247
# Shortest path length: 63.265 for row 1248
# Shortest path length: 8.869 for row 1249
# Shortest path length: 48.412 for row 1250
# Shortest path length: 27.592 for row 1251
# Shortest path length: 21.679 for row 1252
# Shortest path length: 18.51 for row 1253
# Shortest path length: 7.798 for row 1254
# Shortest path length: 6.968 for row 1255
# Shortest path length: 32.386 for row 1256
# Shortest path length: 32.386 for row 1257
# Shortest path length: 30.875 for row 1258
# Shortest path length: 12.845 for row 1259
# Shortest path length: 11.609 for row 1260
# Shortest path length: 11.609 for row 1261
# Shortest path length: 25.939 for row 1262
# Shortest path length: 25.939 for row 1263
# Shortest path length: 75.022 for row 1264
# Shortest path length: 30.212 for row 1265
# Shortest path length: 30.875 for row 1266
# Shortest path length: 29.818 for row 1267
# Shortest path length: 23.104 for row 1268
# Shortest path length: 23.837 for row 1269
# Shortest path length: 14.254 for row 1270
# Shortest path length: 14.783 for row 1271
# Shortest path length: 14.783 for row 1272
# Shortest path length: 10.065 for row 1273
# Shortest path length: 10.065 for row 1274
# Shortest path length: 10.682 for row 1275
# Shortest path length: 7.892 for row 1276
# Shortest path length: 8.511 for row 1277
# Shortest path length: 9.022 for row 1278
# Shortest path length: 9.7 for row 1279
# Shortest path length: 11.568 for row 1280
# Shortest path length: 9.904 for row 1281
# Shortest path length: 4.635 for row 1282
# Shortest path length: 11.062 for row 1283
# Shortest path length: 7.178 for row 1284
# Shortest path length: 7.178 for row 1285
# Shortest path length: 8.511 for row 1286
# Shortest path length: 6.695 for row 1287
# Shortest path length: 6.695 for row 1288
# Shortest path length: 6.695 for row 1289
# Shortest path length: 8.19 for row 1290
# Shortest path length: 8.19 for row 1291
# Shortest path length: 8.19 for row 1292
# Shortest path length: 2.703 for row 1293
# Shortest path length: 1.922 for row 1294
# Shortest path length: 12.508 for row 1295
# Shortest path length: 12.508 for row 1296
# Shortest path length: 7.259 for row 1297
# Shortest path length: 7.881 for row 1298
# Shortest path length: 7.952 for row 1299
# Shortest path length: 7.881 for row 1300
# Shortest path length: 7.952 for row 1301
# Shortest path length: 7.952 for row 1302
# Shortest path length: 7.952 for row 1303
# Shortest path length: 9.7 for row 1304
# Shortest path length: 9.7 for row 1305
# Shortest path length: 6.582 for row 1306
# Shortest path length: 8.109 for row 1307
# Shortest path length: 7.259 for row 1308
# Shortest path length: 12.401 for row 1309
# Shortest path length: 56.963 for row 1310
# Shortest path length: 57.179 for row 1311
# Shortest path length: 59.15 for row 1312
# Shortest path length: 82.161 for row 1313
# Shortest path length: 9.7 for row 1314
# Shortest path length: 4294967.295 for row 1315
# Shortest path length: 90.191 for row 1316
# Shortest path length: 4.103 for row 1317
# Shortest path length: 7.881 for row 1318
# Shortest path length: 7.881 for row 1319
# Shortest path length: 25.187 for row 1320
# Shortest path length: 9.418 for row 1321
# Shortest path length: 9.7 for row 1322
# Shortest path length: 9.7 for row 1323
# Shortest path length: 29.818 for row 1324
# Shortest path length: 29.818 for row 1325
# Shortest path length: 59.15 for row 1326
# Shortest path length: 31.363 for row 1327
# Shortest path length: 91.935 for row 1328
# Shortest path length: 25.267 for row 1329
# Shortest path length: 40.877 for row 1330
# Shortest path length: 40.877 for row 1331
# Shortest path length: 40.877 for row 1332
# Shortest path length: 40.877 for row 1333
# Shortest path length: 50.212 for row 1334
# Shortest path length: 74.491 for row 1335
# Shortest path length: 74.491 for row 1336
# Shortest path length: 74.491 for row 1337
# Shortest path length: 35.65 for row 1338
# Shortest path length: 58.217 for row 1339
# Shortest path length: 74.726 for row 1340
# Shortest path length: 11.707 for row 1341
# Shortest path length: 7.948 for row 1342
# Shortest path length: 8.181 for row 1343
# Shortest path length: 9.977 for row 1344
# Shortest path length: 10.303 for row 1345
# Shortest path length: 9.996 for row 1346
# Shortest path length: 10.625 for row 1347
# Shortest path length: 59.649 for row 1348
# Shortest path length: 9.42 for row 1349
# Shortest path length: 9.494 for row 1350
# Shortest path length: 32.634 for row 1351
# Shortest path length: 7.384 for row 1352
# Shortest path length: 19.367 for row 1353
# Shortest path length: 35.704 for row 1354
# Shortest path length: 26.981 for row 1355
# Shortest path length: 38.73 for row 1356
# Shortest path length: 7.703 for row 1357
# Shortest path length: 7.703 for row 1358
# Shortest path length: 12.895 for row 1359
# Shortest path length: 7.851 for row 1360
# Shortest path length: 13.774 for row 1361
# Shortest path length: 7.703 for row 1362
# Shortest path length: 8.531 for row 1363
# Shortest path length: 7.23 for row 1364
# Shortest path length: 7.23 for row 1365
# Shortest path length: 8.006 for row 1366
# Shortest path length: 6.401 for row 1367
# Shortest path length: 15.788 for row 1368
# Shortest path length: 22.529 for row 1369
# Shortest path length: 9.159 for row 1370
# Shortest path length: 22.133 for row 1371
# Shortest path length: 21.473 for row 1372
# Shortest path length: 19.976 for row 1373
# Shortest path length: 26.068 for row 1374
# Shortest path length: 26.068 for row 1375
# Shortest path length: 26.068 for row 1376
# Shortest path length: 26.068 for row 1377
# Shortest path length: 26.068 for row 1378
# Shortest path length: 22.222 for row 1379
# Shortest path length: 23.563 for row 1380
# Shortest path length: 34.905 for row 1381
# Shortest path length: 19.515 for row 1382
# Shortest path length: 15.944 for row 1383
# Shortest path length: 21.625 for row 1384
# Shortest path length: 23.001 for row 1385
# Shortest path length: 5.781 for row 1386
# Shortest path length: 16.463 for row 1387
# Shortest path length: 23.407 for row 1388
# Shortest path length: 23.407 for row 1389
# Shortest path length: 10.128 for row 1390
# Shortest path length: 13.204 for row 1391
# Shortest path length: 12.474 for row 1392
# Shortest path length: 13.204 for row 1393
# Shortest path length: 12.395 for row 1394
# Shortest path length: 11.58 for row 1395
# Shortest path length: 11.58 for row 1396
# Shortest path length: 11.58 for row 1397
# Shortest path length: 11.58 for row 1398
# Shortest path length: 13.575 for row 1399
# Shortest path length: 16.058 for row 1400
# Shortest path length: 19.212 for row 1401
# Shortest path length: 15.822 for row 1402
# Shortest path length: 24.366 for row 1403
# Shortest path length: 11.182 for row 1404
# Shortest path length: 4.516 for row 1405
# Shortest path length: 21.76 for row 1406
# Shortest path length: 5.781 for row 1407
# Shortest path length: 21.414 for row 1408
# Shortest path length: 19.691 for row 1409
# Shortest path length: 8.404 for row 1410
# Shortest path length: 17.283 for row 1411
# Shortest path length: 17.283 for row 1412
# Shortest path length: 18.997 for row 1413
# Shortest path length: 18.997 for row 1414
# Shortest path length: 16.822 for row 1415
# Shortest path length: 21.766 for row 1416
# Shortest path length: 12.774 for row 1417
# Shortest path length: 15.381 for row 1418
# Shortest path length: 20.805 for row 1419
# Shortest path length: 20.953 for row 1420
# Shortest path length: 5.83 for row 1421
# Shortest path length: 32.049 for row 1422
# Shortest path length: 73.784 for row 1423
# Shortest path length: 48.957 for row 1424
# Shortest path length: 25.598 for row 1425
# Shortest path length: 22.149 for row 1426
# Shortest path length: 17.093 for row 1427
# Shortest path length: 21.716 for row 1428
# Shortest path length: 19.155 for row 1429
# Shortest path length: 24.412 for row 1430
# Shortest path length: 22.259 for row 1431
# Shortest path length: 20.544 for row 1432
# Shortest path length: 14.904 for row 1433
# Shortest path length: 14.904 for row 1434
# Shortest path length: 15.466 for row 1435
# Shortest path length: 14.029 for row 1436
# Shortest path length: 13.082 for row 1437
# Shortest path length: 21.495 for row 1438
# Shortest path length: 21.825 for row 1439
# Shortest path length: 11.001 for row 1440
# Shortest path length: 13.916 for row 1441
# Shortest path length: 16.641 for row 1442
# Shortest path length: 23.122 for row 1443
# Shortest path length: 24.412 for row 1444
# Shortest path length: 21.545 for row 1445
# Shortest path length: 25.678 for row 1446
# Shortest path length: 24.412 for row 1447
# Shortest path length: 22.73 for row 1448
# Shortest path length: 22.73 for row 1449
# Shortest path length: 22.73 for row 1450
# Shortest path length: 22.73 for row 1451
# Shortest path length: 22.73 for row 1452
# Shortest path length: 22.568 for row 1453
# Shortest path length: 22.568 for row 1454
# Shortest path length: 24.239 for row 1455
# Shortest path length: 21.782 for row 1456
# Shortest path length: 17.419 for row 1457
# Shortest path length: 20.73 for row 1458
# Shortest path length: 20.73 for row 1459
# Shortest path length: 20.081 for row 1460
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[226], line 14
#      11     return path_length
#      13 # Apply the function to each row of the GeoDataFrame
# ---> 14 nodes_gdf['time_to_nearest_poi'] = nodes_gdf.apply(compute_shortest_path, pt_network=pt_network, axis=1)
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\geopandas\geodataframe.py:1834, in GeoDataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    1832 @doc(pd.DataFrame)
#    1833 def apply(self, func, axis=0, raw=False, result_type=None, args=(), **kwargs):
# -> 1834     result = super().apply(
#    1835         func, axis=axis, raw=raw, result_type=result_type, args=args, **kwargs
#    1836     )
#    1837     # Reconstruct gdf if it was lost by apply
#    1838     if (
#    1839         isinstance(result, DataFrame)
#    1840         and self._geometry_column_name in result.columns
#    1841     ):
#    1842         # axis=1 apply will split GeometryDType to object, try and cast back
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[226], line 8, in compute_shortest_path(row, pt_network)
#       5 destination_node = row['nearest_poi_node']
#       7 # Calculate the shortest path length between the two nodes
# ----> 8 path_length = pt_network.shortest_path_length(origin_node, destination_node)
#       9 print(f"Shortest path length: {path_length} for row {row.name}")
#      11 return path_length
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandana\network.py:277, in Network.shortest_path_length(self, node_a, node_b, imp_name)
#     252 """
#     253 Return the length of the shortest path between two node IDs in the
#     254 network. Must provide an impedance name if more than one is
#    (...)
#     274
#     275 """
#     276 # map to internal node indexes
# --> 277 node_idx = self._node_indexes(pd.Series([node_a, node_b]))
#     278 node_a = node_idx.iloc[0]
#     279 node_b = node_idx.iloc[1]
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandana\network.py:141, in Network._node_indexes(self, node_ids)
#     139 def _node_indexes(self, node_ids):
#     140     # for some reason, merge is must faster than .loc
# --> 141     df = pd.merge(
#     142         pd.DataFrame({"node_ids": node_ids}),
#     143         pd.DataFrame({"node_idx": self.node_idx}),
#     144         left_on="node_ids",
#     145         right_index=True,
#     146         how="left",
#     147     )
#     148     return df.node_idx
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:886, in _MergeOperation.get_result(self, copy)
#     883 if self.indicator:
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
# --> 886 join_index, left_indexer, right_indexer = self._get_join_info()
#     888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:1142, in _MergeOperation._get_join_info(self)
#    1137     join_index, left_indexer, right_indexer = left_ax.join(
#    1138         right_ax, how=self.how, return_indexers=True, sort=self.sort
#    1139     )
#    1141 elif self.right_index and self.how == "left":
# -> 1142     join_index, left_indexer, right_indexer = _left_join_on_index(
#    1143         left_ax, right_ax, self.left_join_keys, sort=self.sort
#    1144     )
#    1146 elif self.left_index and self.how == "right":
#    1147     join_index, right_indexer, left_indexer = _left_join_on_index(
#    1148         right_ax, left_ax, self.right_join_keys, sort=self.sort
#    1149     )
#
# File c:\Users\ana\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\reshape\merge.py:2385, in _left_join_on_index(left_ax, right_ax, join_keys, sort)
#    2382     rkey = right_ax._values  # type: ignore[assignment]
#    2384 left_key, right_key, count = _factorize_keys(lkey, rkey, sort=sort)
# -> 2385 left_indexer, right_indexer = libjoin.left_outer_join(
#    2386     left_key, right_key, count, sort=sort
#    2387 )
#    2389 if sort or len(left_ax) != len(left_indexer):
#    2390     # if asked to sort or there are 1-to-many matches
#    2391     join_index = left_ax.take(left_indexer)
#
# KeyboardInterrupt:

# %%
# count rows with inf values
print(nodes_gdf[nodes_gdf['time_to_nearest_poi'] == float('inf')].shape[0])

# print the rows with inf values
print(nodes_gdf[nodes_gdf['time_to_nearest_poi'] == float('inf')])
# Out:
# 0
# Empty GeoDataFrame
# Columns: [Referencia, lon, lat, nearest_node, time_to_nearest_poi, block_color, nearest_poi, nearest_poi_node, geometry]
# Index: []

# %%
print(nodes_gdf)
# Out:
#       Referencia       lon        lat  nearest_node  time_to_nearest_poi  \
# 0        8594095 -1.948183  43.299723         29577               14.021
# 1        8594099 -1.948484  43.299120         29577               14.021
# 2        8594100 -1.948365  43.298748         29577               14.021
# 3        8796114 -1.928046  43.315046         64886                4.959
# 4        8796136 -1.928175  43.313904         64886                4.959
# ...          ...       ...        ...           ...                  ...
# 58763    6779028 -2.172469  43.165117         41162              155.734
# 58764    6779053 -2.172669  43.165403         20882              154.897
# 58765    6779097 -2.172889  43.164341         41166              155.162
# 58766    6779001 -2.173457  43.165434         20881              154.120
# 58767    6779052 -2.173675  43.165523         20881              154.120
#
#       block_color                                        nearest_poi  \
# 0            None  Centro de Salud de Martutene (Centro Penitenci...
# 1            None  Centro de Salud de Martutene (Centro Penitenci...
# 2            None  Centro de Salud de Martutene (Centro Penitenci...
# 3            None                           Centro de Salud de Altza
# 4            None                           Centro de Salud de Altza
# ...           ...                                                ...
# 58763        None                                 Consultorio de Aia
# 58764        None                                 Consultorio de Aia
# 58765        None                                 Consultorio de Aia
# 58766        None                                 Consultorio de Aia
# 58767        None                                 Consultorio de Aia
#
#        nearest_poi_node                   geometry
# 0                 81168  POINT (-1.94818 43.29972)
# 1                 81168  POINT (-1.94848 43.29912)
# 2                 81168  POINT (-1.94837 43.29875)
# 3                 24063  POINT (-1.92805 43.31505)
# 4                 24063   POINT (-1.92818 43.3139)
# ...                 ...                        ...
# 58763             19619  POINT (-2.17247 43.16512)
# 58764             19619   POINT (-2.17267 43.1654)
# 58765             19619  POINT (-2.17289 43.16434)
# 58766             19619  POINT (-2.17346 43.16543)
# 58767             19619  POINT (-2.17367 43.16552)
#
# [58768 rows x 9 columns]

# %% [markdown]
# Assign color depending on time

# %%
# Assign colors to the blocks based on the time it takes to reach the nearest POI
nodes_gdf.loc[nodes_gdf['time_to_nearest_poi'] < 3, 'block_color'] = '#00572a'  # Dark Green
nodes_gdf.loc[(nodes_gdf['time_to_nearest_poi'] >= 3) & (nodes_gdf['time_to_nearest_poi'] < 6), 'block_color'] = '#7CB342'  # Green
nodes_gdf.loc[(nodes_gdf['time_to_nearest_poi'] >= 6) & (nodes_gdf['time_to_nearest_poi'] < 10), 'block_color'] = '#FFFF00'  # Yellow
nodes_gdf.loc[(nodes_gdf['time_to_nearest_poi'] >= 10) & (nodes_gdf['time_to_nearest_poi'] < 15), 'block_color'] = '#FFA500'  # Orange
nodes_gdf.loc[(nodes_gdf['time_to_nearest_poi'] >= 15) & (nodes_gdf['time_to_nearest_poi'] < 20), 'block_color'] = '#D50000'  # Red
nodes_gdf.loc[(nodes_gdf['time_to_nearest_poi'] >= 20) & (nodes_gdf['time_to_nearest_poi'] < 25), 'block_color'] = '#8f0340'  # Dark red
nodes_gdf.loc[nodes_gdf['time_to_nearest_poi'] >= 25, 'block_color'] = '#6a1717'  # Purple

# %%
# save gdf
#nodes_gdf.to_file('./outputs/pt/centros_salud_nodes_times_pt_3.geojson', driver='GeoJSON')
